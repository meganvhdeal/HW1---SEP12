# %%
import pandas as pd
# Load the dataset
url = "https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-05-05/villagers.csv"
df = pd.read_csv(url)

# Show the number of rows and columns
print("Shape of the DataFrame (rows, columns):", df.shape)

# Show the number of missing values in each column
print("Missing values in each column:\n", df.isna().sum())

# Observations refer to specific, individual entries in the dataset and is represented by the rows. 
# Variables refer to the different attributes each observation has and is represented by the columns.

# Summary of all columns (including categorical)
df.describe(include='all')

# Load other dataset
titanic_url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv"
titanic_df = pd.read_csv(titanic_url)
titanic_df.describe()

# Attributes are variable containing specific data that belong to an object.
# Methods are functions that are associated with a class and belong to an object.

import pandas as pd

# Load the dataset
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv"
df = pd.read_csv(url)

# View initial summary of missing values
print("Initial missing values:\n", df.isna().sum())

# Remove a column with too many missing values (if any)
# For example, if you want to remove 'deck' because it has a lot of missing data
del df['deck']

# Drop rows with any remaining missing values
df_cleaned = df.dropna()

# View summary of the cleaned dataset
print("\nCleaned dataset (after removing missing data):\n", df_cleaned.isna().sum())
print("\nShape of cleaned dataset:", df_cleaned.shape)
# Out:
# Shape of the DataFrame (rows, columns): (391, 11)
# Missing values in each column:
#  row_n           0
# id              1
# name            0
# gender          0
# species         0
# birthday        0
# personality     0
# song           11
# phrase          0
# full_id         0
# url             0
# dtype: int64
# Initial missing values:
#  survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64
#
# Cleaned dataset (after removing missing data):
#  survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# ...

# %% [markdown]
# count - the number of non-missing values in the dataset.
# mean - the average of the values in the column.
# std - how spread out the values are from the mean
# min - the lowest value in the column.
# 25% - the first quartile.
# 75% - the third quartile.
# 50% - the second quartile.
# max - the highest value in the column.
#
# 1.Provide an example of a "use case" in which using df.dropna() might be peferred over using del df['col']
# df.dropna() removes rows in any column with missing values while del df['col'] will delete entire columns with missing values. So, df.dropna() may be preferred if you want to only delete certain rows with missing values rather than having entire columns with a missing value deleted, which may casue you to lose valuable information.
#
# 2.Provide an example of "the opposite use case" in which using del df['col'] might be preferred over using df.dropna()
# You may have an opposite situation where the columsn do not have important data/information that you need and would have no problem being deleted.
#
# 3.
#
# Discuss why applying del df['col'] before df.dropna() when both are used together could be importaUsing them together could be beneficial and prevent excessive amounts of data from being deleted or removed.nt4.
#
#
# Remove all missing data from one of the datasets you're considering using some combination of del df['col'] and/or df.dropna() and give a justification for your approach, including a "before and after" report of the results of your approach for your da
# Using both del df['col'] and df.dropna() allows the missing values to be removed without losing too much necessary data.
#
# 1.Use your ChatBot session to understand what df.groupby("col1")["col2"].describe() does and then demonstrate and explain this using a different example from the "titanic" data set other than what the ChatBot automatically provide for you
# taset.
